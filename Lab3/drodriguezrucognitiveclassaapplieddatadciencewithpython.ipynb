# %% [markdown]
# *Certificado curso Data Visualization with Python*
#
# ![Certificado Cognitive Class DV0101EN _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)
#
# https://courses.cognitiveclass.ai/certificates/38da2bf20fed42abbf647349213f11d2

# %% [markdown]
# *Certificado Curso Data Analysis with Python*
#
#
#
# ![Certificado IBM DA0101EN _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)
#
# https://courses.cognitiveclass.ai/certificates/a7ae8cfd8896428eb7845ef80aa318fa

# %% [markdown]
# *Certificado Curso Python 101 for Data Science!*
#
# ![Certificado IBM PY0101EN _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)
#
# https://courses.cognitiveclass.ai/certificates/e1d94d569b1949b888eb0d3f370bfdee
